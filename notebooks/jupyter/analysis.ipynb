# %% [markdown]
# # Monthly Sales Analysis
#
# Synthetic sales data analysis — same logic as the marimo version.

# %%
import sys
from pathlib import Path

# Add project root to path so `from src.helpers import ...` works
project_root = str(Path.cwd().parent.parent)
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import random

from src.helpers import calculate_growth_rate

# %%
random.seed(42)
months = [
    "Jan",
    "Feb",
    "Mar",
    "Apr",
    "May",
    "Jun",
    "Jul",
    "Aug",
    "Sep",
    "Oct",
    "Nov",
    "Dec",
]
sales = [random.randint(80, 200) for _ in months]

for month, amount in zip(months, sales):
    print(f"{month}: {amount}")

# %%
growth_rates = []
for i in range(1, len(sales)):
    rate = calculate_growth_rate(sales[i], sales[i - 1])
    growth_rates.append((months[i], rate))

# %%
best_month, best_rate = max(
    growth_rates,
    key=lambda pair: pair[1] if pair[1] is not None else float("-inf"),
)

print(f"Highest growth: {best_month} ({best_rate:.1f}%)")
